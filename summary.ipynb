# %%
# EPOCH[200/200]	Time 154.408 (105.324)	Test_Acc 76.7400 (70.3952)	loss_total 1.1817 (2.5976)	loss_ce 0.0038 (0.2590)	loss_kl 0.4884 (1.7380)	loss_mmd 7.3834 (7.7443)	loss_kl_dropout 4.5113 (5.0257)

# %%
import os
import pandas as pd

# %%
exp_list = os.listdir('saved_models/')

# %%
rows = []
for exp in exp_list:
    with open(os.path.join('saved_models/', exp, 'log.txt'), "r") as f:
        lines = f.readlines()
        try:
            row={}
            for i in range(1,16):
                [k, v] = lines[i].split(':')
                row[k] = v.rstrip("\n")
            row['acc'] = float(lines[-1].split()[5])
            row['cur_epoch'] = float(lines[-1].split()[0])

            rows.append(row)
        except:
            print(exp)
            print(lines[-1])

df = pd.DataFrame(rows)
# Out:
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachTrue_Lambda_SDD0.1_SEED41
# EPOCH[200/200]	Time 79.464 (97.808)	Test_Acc 74.6900 (68.3514)	loss_total 0.1220 (0.3893)	loss_ce 0.0102 (0.2594)	loss_kl 1.1178 (1.2990)
#
# CIFAR100_BaseMethod_B128_SEED41
# EPOCH[200/200]	Time 97.558 (97.533)	Test_Acc 75.1700 (68.5858)	loss_total 0.0054 (0.2641)	loss_ce 0.0054 (0.2641)
#
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED41
# EPOCH[200/200]	Time 61.333 (97.931)	Test_Acc 75.7700 (69.0954)	loss_total 0.0447 (0.3208)	loss_ce 0.0067 (0.2649)	loss_kl 0.3799 (0.5588)
#
# Re_CIFAR100_BaseMethod_B128_SEED101
# EPOCH[200/200]	Time 24.616 (24.667)	Test_Acc 74.7700 (68.3771)	loss_total 0.0054 (0.2702)	loss_ce 0.0054 (0.2702)
#
# Re_CIFAR100_BaseMethod_B128_SEED103
# EPOCH[200/200]	Time 24.591 (24.687)	Test_Acc 75.0800 (68.4616)	loss_total 0.0056 (0.2716)	loss_ce 0.0056 (0.2716)
#
# CIFAR100_BaseMethod_B128_SEED43
# EPOCH[200/200]	Time 70.040 (74.124)	Test_Acc 75.0200 (68.4138)	loss_total 0.0052 (0.2688)	loss_ce 0.0052 (0.2688)
#
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED44
# EPOCH[200/200]	Time 66.751 (73.397)	Test_Acc 76.7300 (70.2615)	loss_total 0.1651 (0.4804)	loss_ce 0.0432 (0.3183)	loss_kl 0.1219 (0.1620)
#
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED43
# EPOCH[200/200]	Time 67.606 (74.130)	Test_Acc 76.8900 (70.4474)	loss_total 0.1653 (0.4807)	loss_ce 0.0430 (0.3189)	loss_kl 0.1223 (0.1618)
#
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED42
# EPOCH[200/200]	Time 61.415 (73.980)	Test_Acc 76.3700 (70.0742)	loss_total 0.1651 (0.4829)	loss_ce 0.0430 (0.3205)	loss_kl 0.1221 (0.1624)
#
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED45
# EPOCH[200/200]	Time 48.821 (73.774)	Test_Acc 76.7900 (70.3362)	loss_total 0.1651 (0.4835)	loss_ce 0.0431 (0.3214)	loss_kl 0.1220 (0.1621)
#
# CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED41
# EPOCH[200/200]	Time 49.599 (49.634)	Test_Acc 77.0900 (70.2208)	loss_total 0.4238 (0.7942)	loss_ce 0.1251 (0.4618)	loss_kl 0.2986 (0.3324)
#
# CIFAR100_SD_Dropout_v2_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED41
# EPOCH[200/200]	Time 39.412 (49.696)	Test_Acc 77.1900 (70.3815)	loss_total 0.1651 (0.4801)	loss_ce 0.0436 (0.3180)	loss_kl 0.1215 (0.1621)
#
# CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED43
# EPOCH[200/200]	Time 73.836 (74.079)	Test_Acc 76.9100 (70.2885)	loss_total 0.4248 (0.7966)	loss_ce 0.1267 (0.4638)	loss_kl 0.2981 (0.3328)
#
# CIFAR100_BaseMethod_B128_SEED44
# EPOCH[200/200]	Time 73.054 (73.331)	Test_Acc 74.4300 (68.1885)	loss_total 0.0055 (0.2668)	loss_ce 0.0055 (0.2668)
#
# CIFAR100_BaseMethod_B128_SEED42
# EPOCH[200/200]	Time 73.704 (73.877)	Test_Acc 74.4900 (68.0961)	loss_total 0.0057 (0.2679)	loss_ce 0.0057 (0.2679)
#
# CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED42
# EPOCH[200/200]	Time 65.042 (73.967)	Test_Acc 77.1600 (70.4312)	loss_total 0.4227 (0.7955)	loss_ce 0.1250 (0.4634)	loss_kl 0.2977 (0.3321)
#
# CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED44
# EPOCH[200/200]	Time 43.666 (73.463)	Test_Acc 76.5500 (69.9334)	loss_total 0.4244 (0.7966)	loss_ce 0.1270 (0.4634)	loss_kl 0.2975 (0.3332)
#
# CIFAR100_BaseMethod_B128_SEED45
# EPOCH[200/200]	Time 73.579 (73.415)	Test_Acc 74.6700 (68.1500)	loss_total 0.0056 (0.2689)	loss_ce 0.0056 (0.2689)
#
# CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED45
# EPOCH[200/200]	Time 49.253 (73.764)	Test_Acc 76.3800 (70.1481)	loss_total 0.4231 (0.7937)	loss_ce 0.1262 (0.4610)	loss_kl 0.2970 (0.3327)
#
# Exp_CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED41
# EPOCH[200/200]	Time 74.376 (74.238)	Test_Acc 77.0900 (70.2208)	loss_total 0.4238 (0.7942)	loss_ce 0.1251 (0.4618)	loss_kl 0.2986 (0.3324)
#
# Exp_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED41
# EPOCH[200/200]	Time 93.251 (93.297)	Test_Acc 76.9500 (71.2751)	loss_total 0.0737 (0.6012)	loss_ce 0.0113 (0.3064)	loss_kl 0.0623 (0.2949)
#
# Exp_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED41
# EPOCH[200/200]	Time 94.145 (93.929)	Test_Acc 77.5900 (71.3637)	loss_total 0.1213 (0.6343)	loss_ce 0.0270 (0.3348)	loss_kl 0.0348 (0.2321)	loss_kl_dropout 0.5951 (0.6739)
#
# Exp_CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED42
# EPOCH[200/200]	Time 74.061 (74.190)	Test_Acc 77.1600 (70.4312)	loss_total 0.4227 (0.7955)	loss_ce 0.1250 (0.4634)	loss_kl 0.2977 (0.3321)
#
# Exp_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED42
# EPOCH[200/200]	Time 93.246 (93.189)	Test_Acc 77.1700 (71.1704)	loss_total 0.0754 (0.6057)	loss_ce 0.0118 (0.3060)	loss_kl 0.0636 (0.2997)
#
# Exp_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED42
# EPOCH[200/200]	Time 93.976 (94.059)	Test_Acc 76.7600 (71.0021)	loss_total 0.1238 (0.6358)	loss_ce 0.0285 (0.3345)	loss_kl 0.0358 (0.2338)	loss_kl_dropout 0.5942 (0.6761)
#
# Exp_CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED43
# EPOCH[200/200]	Time 74.590 (74.272)	Test_Acc 76.9100 (70.2885)	loss_total 0.4248 (0.7966)	loss_ce 0.1267 (0.4638)	loss_kl 0.2981 (0.3328)
#
# Exp_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED43
# EPOCH[200/200]	Time 93.261 (93.169)	Test_Acc 77.3100 (71.3072)	loss_total 0.0778 (0.6102)	loss_ce 0.0120 (0.3087)	loss_kl 0.0658 (0.3015)
#
# Exp_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED43
# EPOCH[200/200]	Time 93.937 (93.855)	Test_Acc 77.2600 (71.2904)	loss_total 0.1231 (0.6393)	loss_ce 0.0268 (0.3372)	loss_kl 0.0358 (0.2342)	loss_kl_dropout 0.6046 (0.6783)
#
# Exp_CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED44
# EPOCH[200/200]	Time 74.578 (74.118)	Test_Acc 76.5500 (69.9334)	loss_total 0.4244 (0.7966)	loss_ce 0.1270 (0.4634)	loss_kl 0.2975 (0.3332)
#
# Exp_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED44
# EPOCH[200/200]	Time 62.495 (92.644)	Test_Acc 77.4400 (71.3821)	loss_total 0.0803 (0.6106)	loss_ce 0.0125 (0.3062)	loss_kl 0.0677 (0.3044)
#
# Exp_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED44
# EPOCH[200/200]	Time 63.333 (92.078)	Test_Acc 76.8800 (71.0519)	loss_total 0.1240 (0.6395)	loss_ce 0.0281 (0.3380)	loss_kl 0.0361 (0.2342)	loss_kl_dropout 0.5987 (0.6733)
#
# Exp_CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD1.0_SEED45
# EPOCH[200/200]	Time 74.182 (74.362)	Test_Acc 76.3800 (70.1481)	loss_total 0.4231 (0.7937)	loss_ce 0.1262 (0.4610)	loss_kl 0.2970 (0.3327)
#
# Exp_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED45
# EPOCH[200/200]	Time 62.931 (62.737)	Test_Acc 77.4600 (71.3621)	loss_total 0.0762 (0.6125)	loss_ce 0.0123 (0.3099)	loss_kl 0.0639 (0.3027)
#
# Exp_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED45
# EPOCH[200/200]	Time 36.030 (62.282)	Test_Acc 77.5800 (71.4486)	loss_total 0.1214 (0.6382)	loss_ce 0.0274 (0.3359)	loss_kl 0.0349 (0.2345)	loss_kl_dropout 0.5913 (0.6772)
#
# debug_CIFAR100_SD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED41
# gamma : 0.1
#
# debug_CIFAR100_SD_Dropout_B128_T3.0_P0.5_DetachFalse_Lambda_SDD0.1_SEED41
# gamma : 0.1
#
# Re_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED101
# EPOCH[200/200]	Time 33.460 (33.172)	Test_Acc 77.2800 (71.2764)	loss_total 0.1245 (0.6381)	loss_ce 0.0285 (0.3357)	loss_kl 0.0358 (0.2338)	loss_kl_dropout 0.6015 (0.6858)
#
# Re_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED101
# EPOCH[200/200]	Time 33.225 (33.138)	Test_Acc 77.9700 (71.5329)	loss_total 0.0798 (0.6144)	loss_ce 0.0129 (0.3099)	loss_kl 0.0669 (0.3045)
#
# Re_CIFAR100_SD_Dropout_B128_T3.0_P0.5_Lambda_SDD1.0_DetachFalse_SEED101
# EPOCH[200/200]	Time 24.207 (24.000)	Test_Acc 76.8900 (70.3986)	loss_total 0.4222 (0.7954)	loss_ce 0.1255 (0.4626)	loss_kl 0.2967 (0.3328)
#
# Re_CIFAR100_BYOT_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED101
# EPOCH[200/200]	Time 36.625 (36.940)	Test_Acc 77.3000 (70.7266)	loss_total 1.1718 (2.5235)	loss_ce 0.0191 (0.2865)	loss_kl 0.7855 (1.9288)	loss_mmd 3.8522 (4.1498)	loss_kl_dropout 0.6051 (0.8606)
#
# Re_CIFAR100_DDGSD_B128_T3.0_Lambda_SelfKD1.0_SEED101
# EPOCH[200/200]	Time 39.842 (39.840)	Test_Acc 76.8400 (71.3290)	loss_total 0.0934 (0.6053)	loss_ce 0.0149 (0.3788)	loss_kl 0.0784 (0.2263)	loss_mmd 0.0158 (0.0242)
#
# Re_CIFAR100_DDGSD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED101
# EPOCH[200/200]	Time 40.468 (40.272)	Test_Acc 77.2000 (71.1590)	loss_total 0.1581 (0.7321)	loss_ce 0.0326 (0.4417)	loss_kl 0.0463 (0.1689)	loss_mmd 0.0090 (0.0173)	loss_kl_dropout 0.7909 (1.2142)
#
# Re_CIFAR100_BYOT_B128_T3.0_Lambda_SelfKD1.0_SEED101
# EPOCH[200/200]	Time 36.909 (36.976)	Test_Acc 77.1400 (70.4870)	loss_total 1.1868 (2.6329)	loss_ce 0.0040 (0.2656)	loss_kl 0.4892 (1.7616)	loss_mmd 7.4257 (7.8183)
#
# Re_CIFAR100_SD_Dropout_B128_T3.0_P0.5_Lambda_SDD1.0_DetachFalse_SEED102
# EPOCH[200/200]	Time 24.076 (24.008)	Test_Acc 77.2200 (70.6351)	loss_total 0.4235 (0.7928)	loss_ce 0.1263 (0.4615)	loss_kl 0.2971 (0.3313)
#
# Re_CIFAR100_BaseMethod_B128_SEED102
# EPOCH[200/200]	Time 24.827 (24.716)	Test_Acc 75.1100 (68.4373)	loss_total 0.0056 (0.2660)	loss_ce 0.0056 (0.2660)
#
# Re_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED102
# EPOCH[200/200]	Time 34.221 (33.359)	Test_Acc 77.4000 (71.3290)	loss_total 0.0763 (0.6046)	loss_ce 0.0116 (0.3049)	loss_kl 0.0647 (0.2998)
#
# Re_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED102
# EPOCH[200/200]	Time 33.472 (33.279)	Test_Acc 76.7700 (71.2395)	loss_total 0.1217 (0.6290)	loss_ce 0.0271 (0.3303)	loss_kl 0.0345 (0.2311)	loss_kl_dropout 0.6011 (0.6759)
#
# Re_CIFAR100_BYOT_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED102
# EPOCH[200/200]	Time 36.988 (36.985)	Test_Acc 77.4600 (70.9158)	loss_total 1.1648 (2.5076)	loss_ce 0.0187 (0.2849)	loss_kl 0.7833 (1.9157)	loss_mmd 3.8083 (4.1316)	loss_kl_dropout 0.6023 (0.8544)
#
# Re_CIFAR100_BYOT_B128_T3.0_Lambda_SelfKD1.0_SEED102
# EPOCH[200/200]	Time 36.987 (36.900)	Test_Acc 76.8700 (69.9813)	loss_total 1.1881 (2.6167)	loss_ce 0.0037 (0.2665)	loss_kl 0.4847 (1.7481)	loss_mmd 7.4814 (7.7690)
#
# Re_CIFAR100_DDGSD_B128_T3.0_Lambda_SelfKD1.0_SEED102
# EPOCH[200/200]	Time 40.124 (39.861)	Test_Acc 75.7800 (70.2377)	loss_total 0.1014 (0.6497)	loss_ce 0.0162 (0.4098)	loss_kl 0.0852 (0.2398)	loss_mmd 0.0168 (0.0258)
#
# Re_CIFAR100_DDGSD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED102
# EPOCH[200/200]	Time 40.442 (40.327)	Test_Acc 77.2800 (71.3535)	loss_total 0.1531 (0.7322)	loss_ce 0.0314 (0.4462)	loss_kl 0.0440 (0.1657)	loss_mmd 0.0088 (0.0170)	loss_kl_dropout 0.7761 (1.2020)
#
# Re_CIFAR100_SD_Dropout_B128_T3.0_P0.5_Lambda_SDD1.0_DetachFalse_SEED103
# ####################Save Best Model####################
#
# Re_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED103
# EPOCH[200/200]	Time 32.706 (33.248)	Test_Acc 76.5600 (70.9601)	loss_total 0.1243 (0.6416)	loss_ce 0.0277 (0.3379)	loss_kl 0.0368 (0.2356)	loss_kl_dropout 0.5980 (0.6810)
#
# Re_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED103
# EPOCH[200/200]	Time 33.570 (33.279)	Test_Acc 76.9400 (71.0262)	loss_total 0.0759 (0.6089)	loss_ce 0.0119 (0.3087)	loss_kl 0.0640 (0.3002)
#
# Re_CIFAR100_SD_Dropout_B128_T3.0_P0.5_Lambda_SDD1.0_DetachFalse_SEED104
# EPOCH[200/200]	Time 24.070 (23.964)	Test_Acc 76.2500 (69.8471)	loss_total 0.4245 (0.7920)	loss_ce 0.1264 (0.4592)	loss_kl 0.2981 (0.3327)
#
# Re_CIFAR100_BYOT_B128_T3.0_Lambda_SelfKD1.0_SEED103
# EPOCH[200/200]	Time 37.071 (37.010)	Test_Acc 77.1100 (70.4160)	loss_total 1.1737 (2.5976)	loss_ce 0.0037 (0.2616)	loss_kl 0.4837 (1.7451)	loss_mmd 7.3464 (7.6546)
#
# Re_CIFAR100_BYOT_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED103
# EPOCH[200/200]	Time 36.889 (37.151)	Test_Acc 77.7400 (70.8656)	loss_total 1.1550 (2.5160)	loss_ce 0.0190 (0.2865)	loss_kl 0.7908 (1.9294)	loss_mmd 3.6434 (4.0712)	loss_kl_dropout 0.5993 (0.8586)
#
# Re_CIFAR100_BaseMethod_B128_SEED104
# EPOCH[200/200]	Time 24.620 (24.712)	Test_Acc 74.6000 (68.1432)	loss_total 0.0054 (0.2691)	loss_ce 0.0054 (0.2691)
#
# Re_CIFAR100_DDGSD_B128_T3.0_Lambda_SelfKD1.0_SEED103
# EPOCH[200/200]	Time 39.767 (39.861)	Test_Acc 77.1100 (71.5663)	loss_total 0.0918 (0.5958)	loss_ce 0.0144 (0.3748)	loss_kl 0.0773 (0.2208)	loss_mmd 0.0150 (0.0233)
#
# Re_CIFAR100_DDGSD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED103
# EPOCH[200/200]	Time 40.245 (40.350)	Test_Acc 77.1200 (71.2084)	loss_total 0.1576 (0.7239)	loss_ce 0.0325 (0.4378)	loss_kl 0.0464 (0.1656)	loss_mmd 0.0089 (0.0170)	loss_kl_dropout 0.7870 (1.2043)
#
# Re_CIFAR100_SD_Dropout_B128_T3.0_P0.5_Lambda_SDD1.0_DetachFalse_SEED105
# EPOCH[200/200]	Time 23.934 (24.000)	Test_Acc 76.8900 (70.2547)	loss_total 0.4223 (0.7919)	loss_ce 0.1252 (0.4603)	loss_kl 0.2970 (0.3317)
#
# Re_CIFAR100_BaseMethod_B128_SEED105
# EPOCH[200/200]	Time 24.482 (24.712)	Test_Acc 74.9300 (68.3708)	loss_total 0.0054 (0.2695)	loss_ce 0.0054 (0.2695)
# Re_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED104
# EPOCH[200/200]	Time 33.494 (33.429)	Test_Acc 76.7500 (71.1281)	loss_total 0.1228 (0.6348)	loss_ce 0.0271 (0.3338)	loss_kl 0.0354 (0.2334)	loss_kl_dropout 0.6029 (0.6763)
#
# Re_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED104
# EPOCH[200/200]	Time 32.801 (33.295)	Test_Acc 77.0700 (71.0892)	loss_total 0.0742 (0.6047)	loss_ce 0.0115 (0.3076)	loss_kl 0.0627 (0.2971)
#
# Re_CIFAR100_BYOT_B128_T3.0_Lambda_SelfKD1.0_SEED104
# EPOCH[200/200]	Time 36.963 (37.062)	Test_Acc 76.8200 (70.3397)	loss_total 1.1607 (2.5952)	loss_ce 0.0039 (0.2642)	loss_kl 0.4751 (1.7431)	loss_mmd 7.2917 (7.6226)
#
# Re_CIFAR100_BYOT_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED104
# EPOCH[200/200]	Time 37.031 (36.845)	Test_Acc 77.3800 (70.8844)	loss_total 1.1658 (2.5119)	loss_ce 0.0192 (0.2862)	loss_kl 0.7952 (1.9267)	loss_mmd 3.7072 (4.0616)	loss_kl_dropout 0.6023 (0.8540)
#
# Re_CIFAR100_DDGSD_B128_T3.0_Lambda_SelfKD1.0_SEED104
# EPOCH[200/200]	Time 39.852 (39.851)	Test_Acc 76.6900 (70.8668)	loss_total 0.0986 (0.6411)	loss_ce 0.0158 (0.4048)	loss_kl 0.0827 (0.2362)	loss_mmd 0.0167 (0.0256)
#
# Re_CIFAR100_DDGSD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED104
# EPOCH[200/200]	Time 40.212 (40.306)	Test_Acc 77.0400 (71.0962)	loss_total 0.1553 (0.7356)	loss_ce 0.0319 (0.4482)	loss_kl 0.0450 (0.1664)	loss_mmd 0.0089 (0.0171)	loss_kl_dropout 0.7832 (1.2090)
#
# Re_CIFAR100_CS_KD_B128_T3.0_Lambda_SelfKD1.0_SEED105
# EPOCH[200/200]	Time 33.499 (33.228)	Test_Acc 77.3800 (71.1655)	loss_total 0.0786 (0.6132)	loss_ce 0.0120 (0.3099)	loss_kl 0.0666 (0.3033)
#
# Re_CIFAR100_CS_KD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED105
# EPOCH[200/200]	Time 34.065 (33.861)	Test_Acc 77.2700 (71.2876)	loss_total 0.1226 (0.6371)	loss_ce 0.0270 (0.3355)	loss_kl 0.0358 (0.2341)	loss_kl_dropout 0.5991 (0.6755)
#
# Re_CIFAR100_BYOT_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED105
# EPOCH[200/200]	Time 36.429 (36.600)	Test_Acc 77.2100 (70.7238)	loss_total 1.1918 (2.5279)	loss_ce 0.0187 (0.2839)	loss_kl 0.8015 (1.9323)	loss_mmd 3.9172 (4.1935)	loss_kl_dropout 0.6006 (0.8550)
#
# Re_CIFAR100_BYOT_B128_T3.0_Lambda_SelfKD1.0_SEED105
# EPOCH[200/200]	Time 36.610 (36.985)	Test_Acc 76.9600 (70.1994)	loss_total 1.1461 (2.5632)	loss_ce 0.0038 (0.2609)	loss_kl 0.4699 (1.7182)	loss_mmd 7.1945 (7.5597)
#
# Re_CIFAR100_DDGSD_B128_T3.0_Lambda_SelfKD1.0_SEED105
# EPOCH[200/200]	Time 39.316 (39.602)	Test_Acc 76.9000 (71.4024)	loss_total 0.0941 (0.6124)	loss_ce 0.0149 (0.3831)	loss_kl 0.0791 (0.2292)	loss_mmd 0.0159 (0.0245)
#
# Re_CIFAR100_DDGSD_Dropout_B128_T3.0_Lambda_SelfKD1.0_P0.5_Lambda_SDD0.1_DetachFalse_SEED105
# EPOCH[200/200]	Time 39.545 (40.049)	Test_Acc 77.2200 (71.5829)	loss_total 0.1440 (0.6898)	loss_ce 0.0290 (0.4160)	loss_kl 0.0396 (0.1589)	loss_mmd 0.0081 (0.0163)	loss_kl_dropout 0.7539 (1.1488)

# %%
lines[-1].split()
# Out:
# ['EPOCH[200/200]',
#  'Time',
#  '79.433',
#  '(97.188)',
#  'Test_Acc',
#  '58.7332',
#  '(48.2686)',
#  'loss_total',
#  '0.4363',
#  '(1.3426)',
#  'loss_ce',
#  '0.3486',
#  '(1.2377)',
#  'loss_kl',
#  '0.8772',
#  '(1.0484)',
#  'loss_kl_dropout',
#  '24.8649',
#  '(19.0890)']

# %%
df.to_csv('out.csv')

# %%
df
# Out:
#                                             exp_name  gpu  num_workers  seed   \
# 0    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    0            1    41
# 1    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    0            1    42
# 2    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    0            1    41
# 3    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    0            1    42
# 4    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    1            1    41
# 5    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    2            1    41
# 6    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    1            1    42
# 7    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    2            1    42
# 8    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    1            1    41
# 9    CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    2            1    41
# 10   CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    1            1    42
# 11   CIFAR100_BYOT_Dropout_byot_resnet18_cifar__p0...    2            1    42
# 12   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    3            1    42
# 13   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    3            1    41
# 14   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    3            1    42
# 15   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    4            1    41
# 16   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    5            1    41
# 17   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    4            1    42
# 18   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    5            1    42
# 19   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    5            1    41
# 20   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    4            1    42
# 21   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    5            1    42
# 22   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    6            1    41
# 23   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    6            1    42
# 24   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    6            1    41
# 25   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    6            1    42
# 26   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    1            1    42
# 27   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    2            1    41
# 28   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    3            1    41
# 29   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    2            1    42
# 30   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    3            1    42
# 31   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    2            1    41
# 32   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    3            1    41
# 33   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    2            1    42
# 34   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    3            1    42
# 35   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    3            1    41
# 36   CIFAR100_DML_Dropout_resnet18_cifar__p0.5_t3....    4            1    41
# 37   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    7            1    41
# 38   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    1            1    41
# 39   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    0            1    41
# 40   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    7            1    42
# 41   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    7            1    41
# 42   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    0            1    41
# 43   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    7            1    42
# 44   CUB200_BYOT_Dropout_byot_resnet18__p0.5_t3.0_...    0            1    42
# 45   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    1            1    41
# 46   CUB200_DML_Dropout_resnet18__p0.5_t3.0_alpha0...    1            1    42
#
#    resume    dataset         method              backbone  epochs   \
# 0            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 1            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 2            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 3            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 4            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 5            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 6            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 7            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 8            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 9            CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 10           CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 11           CIFAR100   BYOT_Dropout   byot_resnet18_cifar     200
# 12           CIFAR100    DML_Dropout        resnet18_cifar     200
# 13           CIFAR100    DML_Dropout        resnet18_cifar     200
# 14           CIFAR100    DML_Dropout        resnet18_cifar     200
# 15           CIFAR100    DML_Dropout        resnet18_cifar     200
# 16           CIFAR100    DML_Dropout        resnet18_cifar     200
# 17           CIFAR100    DML_Dropout        resnet18_cifar     200
# 18           CIFAR100    DML_Dropout        resnet18_cifar     200
# 19           CIFAR100    DML_Dropout        resnet18_cifar     200
# 20           CIFAR100    DML_Dropout        resnet18_cifar     200
# 21           CIFAR100    DML_Dropout        resnet18_cifar     200
# 22             CUB200   BYOT_Dropout         byot_resnet18     200
# 23             CUB200   BYOT_Dropout         byot_resnet18     200
# 24             CUB200   BYOT_Dropout         byot_resnet18     200
# 25             CUB200   BYOT_Dropout         byot_resnet18     200
# 26             CUB200    DML_Dropout              resnet18     200
# 27             CUB200    DML_Dropout              resnet18     200
# 28             CUB200    DML_Dropout              resnet18     200
# 29             CUB200    DML_Dropout              resnet18     200
# 30             CUB200    DML_Dropout              resnet18     200
# 31             CUB200    DML_Dropout              resnet18     200
# 32             CUB200    DML_Dropout              resnet18     200
# 33             CUB200    DML_Dropout              resnet18     200
# 34             CUB200    DML_Dropout              resnet18     200
# 35           CIFAR100    DML_Dropout        resnet18_cifar     200
# 36           CIFAR100    DML_Dropout        resnet18_cifar     200
# 37             CUB200   BYOT_Dropout         byot_resnet18     200
# 38             CUB200    DML_Dropout              resnet18     200
# 39             CUB200   BYOT_Dropout         byot_resnet18     200
# 40             CUB200   BYOT_Dropout         byot_resnet18     200
# 41             CUB200   BYOT_Dropout         byot_resnet18     200
# 42             CUB200   BYOT_Dropout         byot_resnet18     200
# 43             CUB200   BYOT_Dropout         byot_resnet18     200
# 44             CUB200   BYOT_Dropout         byot_resnet18     200
# 45             CUB200    DML_Dropout              resnet18     200
# 46             CUB200    DML_Dropout              resnet18     200
#
#    batch_size     t     p  alpha  beta  detach       acc
# 0          128   3.0   0.5    0.0   0.1   False  77.1800
# 1          128   3.0   0.5    0.0   0.1   False  77.1900
# 2          128   3.0   0.5    0.0   1.0   False  76.8700
# 3          128   3.0   0.5    0.0   1.0   False  76.6000
# 4          128   3.0   0.5    0.1   0.1   False  77.6800
# 5          128   3.0   0.5    0.1   0.1    True  78.3900
# 6          128   3.0   0.5    0.1   0.1   False  77.7300
# 7          128   3.0   0.5    0.1   0.1    True  77.8700
# 8          128   3.0   0.5    0.1   1.0   False  77.3300
# 9          128   3.0   0.5    0.1   1.0    True  77.7100
# 10         128   3.0   0.5    0.1   1.0   False  77.8400
# 11         128   3.0   0.5    0.1   1.0    True  77.2200
# 12         128   3.0   0.5    0.0   0.1   False  77.3200
# 13         128   3.0   0.5    0.0   1.0   False  79.0500
# 14         128   3.0   0.5    0.0   1.0   False  78.7600
# 15         128   3.0   0.5    0.1   0.1   False  78.0500
# 16         128   3.0   0.5    0.1   0.1    True  77.6900
# 17         128   3.0   0.5    0.1   0.1   False  77.7200
# 18         128   3.0   0.5    0.1   0.1    True  77.4300
# 19         128   3.0   0.5    0.1   1.0    True  78.6200
# 20         128   3.0   0.5    0.1   1.0   False  78.9000
# 21         128   3.0   0.5    0.1   1.0    True  78.7700
# 22          32   3.0   0.5    0.0   0.1   False  60.8561
# 23          32   3.0   0.5    0.0   0.1   False  60.9424
# 24          32   3.0   0.5    0.0   1.0   False  63.0307
# 25          32   3.0   0.5    0.0   1.0   False  62.5302
# 26          32   3.0   0.5    0.0   1.0   False  61.3738
# 27          32   3.0   0.5    0.1   0.1   False  65.3952
# 28          32   3.0   0.5    0.1   0.1    True  63.7729
# 29          32   3.0   0.5    0.1   0.1   False  65.5506
# 30          32   3.0   0.5    0.1   0.1    True  63.8246
# 31          32   3.0   0.5    0.1   1.0   False  66.1546
# 32          32   3.0   0.5    0.1   1.0    True  65.1536
# 33          32   3.0   0.5    0.1   1.0   False  65.2399
# 34          32   3.0   0.5    0.1   1.0    True  64.7049
# 35         128   3.0   0.5    0.0   0.1   False  77.8400
# 36         128   3.0   0.5    0.1   1.0   False  78.6100
# 37          32   3.0   0.5    0.1   0.1   False  68.5537
# 38          32   3.0   0.5    0.0   1.0   False  61.6672
# 39          32   3.0   0.5    0.1   0.1    True  66.3445
# 40          32   3.0   0.5    0.1   0.1   False  68.0014
# 41          32   3.0   0.5    0.1   1.0   False  72.5060
# 42          32   3.0   0.5    0.1   1.0    True  68.6918
# 43          32   3.0   0.5    0.1   1.0   False  72.0573
# 44          32   3.0   0.5    0.1   1.0    True  68.7435
# 45          32   3.0   0.5    0.0   0.1   False  58.9230
# 46          32   3.0   0.5    0.0   0.1   False  58.7332

# %%
ㄹ
